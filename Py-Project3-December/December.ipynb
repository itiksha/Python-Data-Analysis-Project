# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_excel(r'c:\Users\ItikshaMittal(Annale\OneDrive - OneWorkplace (1)\Desktop\Python\Py-Project3-December\Onyx Data -DataDNA Dataset Challenge - Christmas Sales and Trends - December 2023.xlsx', sheet_name='Onyx Data -DataDNA Dataset Chal')

# %%
df.head(5)
# Out:
#    TransactionID       Date      Time  CustomerID  Age Gender Location  \
# 0              1 2020-12-24  07:27:59         441   27  Other  City_15
# 1              2 2022-11-18  14:36:39         340   43   Male  City_13
# 2              3 2019-12-26  20:23:50          31   25  Other   City_7
# 3              4 2018-11-13  23:08:08          39   64   Male  City_20
# 4              5 2020-12-13  04:38:08         344   26  Other  City_10
#
#    StoreID  OnlineOrderFlag  ProductID  ...  PaymentType PromotionApplied  \
# 0      NaN             True        106  ...  Credit Card            False
# 1      NaN             True        816  ...  Credit Card             True
# 2     92.0            False        508  ...  Credit Card            False
# 3    100.0            False        710  ...   Debit Card            False
# 4     90.0            False        687  ...         Cash            False
#
#    DiscountAmount  GiftWrap  ShippingMethod DeliveryTime  Weather  \
# ...

# %%
sns.violinplot(data=df, x='Age', y ='Gender')
# Out:
# <Axes: xlabel='Age', ylabel='Gender'>

# %%
sns.lmplot(data=df, x = 'CustomerID', y='Sales')

# %%
df['Date'].min()
# Out:
# Timestamp('2018-11-01 00:00:00')

# %%
df['Date'].max()
# Out:
# Timestamp('2023-12-31 00:00:00')

# %%
df['Month'] = df['Date'].apply(lambda x: x.strftime('%y-%m'))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   TransactionID         10000 non-null  int64
#  1   Date                  10000 non-null  datetime64[ns]
#  2   Time                  10000 non-null  object
#  3   CustomerID            10000 non-null  int64
#  4   Age                   10000 non-null  int64
#  5   Gender                10000 non-null  object
#  6   Location              10000 non-null  object
#  7   StoreID               4582 non-null   float64
#  8   OnlineOrderFlag       10000 non-null  bool
#  9   ProductID             10000 non-null  int64
#  10  ProductName           10000 non-null  object
#  11  Category              10000 non-null  object
#  12  Quantity              10000 non-null  int64
#  13  UnitPrice             10000 non-null  float64
#  14  TotalPrice            10000 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# TransactionID              0
# Date                       0
# Time                       0
# CustomerID                 0
# Age                        0
# Gender                     0
# Location                   0
# StoreID                 5418
# OnlineOrderFlag            0
# ProductID                  0
# ProductName                0
# Category                   0
# Quantity                   0
# UnitPrice                  0
# TotalPrice                 0
# PaymentType                0
# PromotionApplied           0
# DiscountAmount             0
# GiftWrap                   0
# ShippingMethod          4582
# DeliveryTime            4582
# Weather                    0
# Event                   2838
# CustomerSatisfaction       0
# ReturnFlag                 0
# Month                      0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# TransactionID              0
# Date                       0
# Time                       0
# CustomerID                 0
# Age                        0
# Gender                     0
# Location                   0
# StoreID                 5418
# OnlineOrderFlag            0
# ProductID                  0
# ProductName                0
# Category                   0
# Quantity                   0
# UnitPrice                  0
# TotalPrice                 0
# PaymentType                0
# PromotionApplied           0
# DiscountAmount             0
# GiftWrap                   0
# ShippingMethod          4582
# DeliveryTime            4582
# Weather                    0
# Event                   2838
# CustomerSatisfaction       0
# ReturnFlag                 0
# Month                      0
# dtype: int64

# %%
df.head()
# Out:
#    TransactionID       Date      Time  CustomerID  Age Gender Location  \
# 0              1 2020-12-24  07:27:59         441   27  Other  City_15
# 1              2 2022-11-18  14:36:39         340   43   Male  City_13
# 2              3 2019-12-26  20:23:50          31   25  Other   City_7
# 3              4 2018-11-13  23:08:08          39   64   Male  City_20
# 4              5 2020-12-13  04:38:08         344   26  Other  City_10
#
#    StoreID  OnlineOrderFlag  ProductID  ... PromotionApplied DiscountAmount  \
# 0      NaN             True        106  ...            False            0.0
# 1      NaN             True        816  ...             True            0.0
# 2     92.0            False        508  ...            False            0.0
# 3    100.0            False        710  ...            False            0.0
# 4     90.0            False        687  ...            False            0.0
#
#    GiftWrap  ShippingMethod  DeliveryTime Weather             Event  \
# ...

# %%
df.groupby(['Date','ProductID'])['DeliveryTime'].sum()
# Out:
# Date        ProductID
# 2018-11-01  4            0.0
#             15           0.0
#             26           1.0
#             40           0.0
#             152          0.0
#                         ...
# 2023-12-31  726          5.0
#             736          3.0
#             807          2.0
#             934          1.0
#             958          3.0
# Name: DeliveryTime, Length: 9859, dtype: float64

# %%
df.DeliveryTime.fillna(df.groupby(['Date','Category'])['DeliveryTime'].transform('sum'))
# Out:
# 0        5.0
# 1        3.0
# 2        7.0
# 3        5.0
# 4       11.0
#         ...
# 9995     4.0
# 9996     5.0
# 9997     9.0
# 9998     1.0
# 9999     2.0
# Name: DeliveryTime, Length: 10000, dtype: float64

# %%
df['Weather'] = df['Weather'].astype('category')
df['Weather'] = df['Weather'].cat.codes
df['Weather']
# Out:
# 0       1
# 1       2
# 2       0
# 3       0
# 4       2
#        ..
# 9995    2
# 9996    0
# 9997    1
# 9998    2
# 9999    1
# Name: Weather, Length: 10000, dtype: int8

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.ensemble import RandomForestRegressor

# %%
df['Weather'].fillna(df.groupby(['TransactionID','Date'])['Weather'].transform('median'))
# Out:
# 0       1
# 1       2
# 2       0
# 3       0
# 4       2
#        ..
# 9995    2
# 9996    0
# 9997    1
# 9998    2
# 9999    1
# Name: Weather, Length: 10000, dtype: int8

# %%
df['DeliveryTime']
# Out:
# 0       5.0
# 1       3.0
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 9995    4.0
# 9996    5.0
# 9997    NaN
# 9998    1.0
# 9999    2.0
# Name: DeliveryTime, Length: 10000, dtype: float64

# %%
df['Event'].fillna("Christmas Festival")
df['DeliveryTime'].bfill()
# Out:
# 0       5.0
# 1       3.0
# 2       2.0
# 3       2.0
# 4       2.0
#        ...
# 9995    4.0
# 9996    5.0
# 9997    1.0
# 9998    1.0
# 9999    2.0
# Name: DeliveryTime, Length: 10000, dtype: float64

# %%
df.DeliveryTime.fillna(df.DeliveryTime.mean())
# df.DeliveryTime
# Out:
# 0       5.000000
# 1       3.000000
# 2       3.004245
# 3       3.004245
# 4       3.004245
#           ...
# 9995    4.000000
# 9996    5.000000
# 9997    3.004245
# 9998    1.000000
# 9999    2.000000
# Name: DeliveryTime, Length: 10000, dtype: float64

# %%
df['Sales'] = df['Quantity'] * df['UnitPrice']
df['Sales']
# Out:
# 0       483.931273
# 1        95.279579
# 2       104.743291
# 3       318.236463
# 4       172.152122
#            ...
# 9995     91.072121
# 9996     41.538590
# 9997     73.683280
# 9998     61.004291
# 9999    328.028730
# Name: Sales, Length: 10000, dtype: float64

# %%
df.isnull().sum()
# Out:
# TransactionID              0
# Date                       0
# Time                       0
# CustomerID                 0
# Age                        0
# Gender                     0
# Location                   0
# StoreID                 5418
# OnlineOrderFlag            0
# ProductID                  0
# ProductName                0
# Category                   0
# Quantity                   0
# UnitPrice                  0
# TotalPrice                 0
# PaymentType                0
# PromotionApplied           0
# DiscountAmount             0
# GiftWrap                   0
# ShippingMethod          4582
# DeliveryTime            4582
# Weather                    0
# Event                   2838
# CustomerSatisfaction       0
# ReturnFlag                 0
# Month                      0
# Sales                      0
# dtype: int64

# %%
plt.plot(df['Month'], df['Sales']).head(6)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 plt.plot(df['Month'], df['Sales']).head(6)
#
# AttributeError: 'list' object has no attribute 'head'

# %%
df
# Out:
#       TransactionID       Date      Time  CustomerID  Age  Gender Location  \
# 0                 1 2020-12-24  07:27:59         441   27   Other  City_15
# 1                 2 2022-11-18  14:36:39         340   43    Male  City_13
# 2                 3 2019-12-26  20:23:50          31   25   Other   City_7
# 3                 4 2018-11-13  23:08:08          39   64    Male  City_20
# 4                 5 2020-12-13  04:38:08         344   26   Other  City_10
# ...             ...        ...       ...         ...  ...     ...      ...
# 9995           9996 2022-12-21  12:05:06         245   25   Other  City_10
# 9996           9997 2022-11-24  17:28:29         295   46  Female  City_17
# 9997           9998 2021-11-02  23:20:58         202   46  Female  City_13
# 9998           9999 2020-11-11  11:33:17         310   64   Other   City_8
# 9999          10000 2022-11-16  17:01:01         469   39  Female  City_15
#
#       StoreID  OnlineOrderFlag  ProductID  ... PromotionApplied  \
# ...

# %%
df.drop([0,1,2,3,4], axis=0)
# Out:
#       TransactionID       Date      Time  CustomerID  Age  Gender Location  \
# 5                 6 2018-11-26  03:17:17         307   18    Male   City_4
# 6                 7 2020-12-08  08:26:56         368   63  Female   City_3
# 7                 8 2020-12-03  16:02:24         121   48   Other   City_1
# 8                 9 2020-11-10  14:41:38         464   58   Other  City_19
# 9                10 2019-11-16  00:08:13         252   41  Female  City_16
# ...             ...        ...       ...         ...  ...     ...      ...
# 9995           9996 2022-12-21  12:05:06         245   25   Other  City_10
# 9996           9997 2022-11-24  17:28:29         295   46  Female  City_17
# 9997           9998 2021-11-02  23:20:58         202   46  Female  City_13
# 9998           9999 2020-11-11  11:33:17         310   64   Other   City_8
# 9999          10000 2022-11-16  17:01:01         469   39  Female  City_15
#
#       StoreID  OnlineOrderFlag  ProductID  ... PromotionApplied  \
# ...

# %%
pd.isnull(df).sum()
# Out:
# TransactionID              0
# Date                       0
# Time                       0
# CustomerID                 0
# Age                        0
# Gender                     0
# Location                   0
# StoreID                 5418
# OnlineOrderFlag            0
# ProductID                  0
# ProductName                0
# Category                   0
# Quantity                   0
# UnitPrice                  0
# TotalPrice                 0
# PaymentType                0
# PromotionApplied           0
# DiscountAmount             0
# GiftWrap                   0
# ShippingMethod          4582
# DeliveryTime            4582
# Weather                    0
# Event                   2838
# CustomerSatisfaction       0
# ReturnFlag                 0
# Month                      0
# dtype: int64

# %%
df_cleaned = df.dropna(subset=['Event'])
# df_cleaned
df_cleaned.isnull().sum()
df_cleaned.shape
# Out:
# (7162, 26)

# %%
df.isnull()
# Out:
#       TransactionID   Date   Time  CustomerID    Age  Gender  Location  \
# 0             False  False  False       False  False   False     False
# 1             False  False  False       False  False   False     False
# 2             False  False  False       False  False   False     False
# 3             False  False  False       False  False   False     False
# 4             False  False  False       False  False   False     False
# ...             ...    ...    ...         ...    ...     ...       ...
# 9995          False  False  False       False  False   False     False
# 9996          False  False  False       False  False   False     False
# 9997          False  False  False       False  False   False     False
# 9998          False  False  False       False  False   False     False
# 9999          False  False  False       False  False   False     False
#
#       StoreID  OnlineOrderFlag  ProductID  ...  PromotionApplied  \
# ...

# %%
df.shape
# Out:
# (10000, 26)

# %%
dr = df.dropna(axis=1)
c = dr.head()
c.isnull().sum()
# Out:
# TransactionID           0
# Date                    0
# Time                    0
# CustomerID              0
# Age                     0
# Gender                  0
# Location                0
# OnlineOrderFlag         0
# ProductID               0
# ProductName             0
# Category                0
# Quantity                0
# UnitPrice               0
# TotalPrice              0
# PaymentType             0
# PromotionApplied        0
# DiscountAmount          0
# GiftWrap                0
# Weather                 0
# CustomerSatisfaction    0
# ReturnFlag              0
# Month                   0
# dtype: int64

# %%
df.shape
# Out:
# (10000, 26)

# %%
df.head()
# Out:
#    TransactionID       Date      Time  CustomerID  Age Gender Location  \
# 0              1 2020-12-24  07:27:59         441   27  Other  City_15
# 1              2 2022-11-18  14:36:39         340   43   Male  City_13
# 2              3 2019-12-26  20:23:50          31   25  Other   City_7
# 3              4 2018-11-13  23:08:08          39   64   Male  City_20
# 4              5 2020-12-13  04:38:08         344   26  Other  City_10
#
#    StoreID  OnlineOrderFlag  ProductID  ... PromotionApplied DiscountAmount  \
# 0      NaN             True        106  ...            False            0.0
# 1      NaN             True        816  ...             True            0.0
# 2     92.0            False        508  ...            False            0.0
# 3    100.0            False        710  ...            False            0.0
# 4     90.0            False        687  ...            False            0.0
#
#    GiftWrap  ShippingMethod  DeliveryTime Weather             Event  \
# ...

# %%
df.dtypes
# Out:
# TransactionID                    int64
# Date                    datetime64[ns]
# Time                            object
# CustomerID                       int64
# Age                              int64
# Gender                          object
# Location                        object
# StoreID                        float64
# OnlineOrderFlag                   bool
# ProductID                        int64
# ProductName                     object
# Category                        object
# Quantity                         int64
# UnitPrice                      float64
# TotalPrice                     float64
# PaymentType                     object
# PromotionApplied                  bool
# DiscountAmount                 float64
# GiftWrap                          bool
# ShippingMethod                  object
# DeliveryTime                   float64
# Weather                         object
# Event                           object
# CustomerSatisfaction             int64
# ...

# %%
df.astype({'Gender': 'str'}, copy=True)
df.dtypes
# Out:
# TransactionID                    int64
# Date                    datetime64[ns]
# Time                            object
# CustomerID                       int64
# Age                              int64
# Gender                          object
# Location                        object
# StoreID                        float64
# OnlineOrderFlag                   bool
# ProductID                        int64
# ProductName                     object
# Category                        object
# Quantity                         int64
# UnitPrice                      float64
# TotalPrice                     float64
# PaymentType                     object
# PromotionApplied                  bool
# DiscountAmount                 float64
# GiftWrap                          bool
# ShippingMethod                  object
# DeliveryTime                   float64
# Weather                         object
# Event                           object
# CustomerSatisfaction             int64
# ...

# %%
df.dtypes
# Out:
# TransactionID                    int64
# Date                    datetime64[ns]
# Time                            object
# CustomerID                       int64
# Age                              int64
# Gender                          object
# Location                        object
# StoreID                        float64
# OnlineOrderFlag                   bool
# ProductID                        int64
# ProductName                     object
# Category                        object
# Quantity                         int64
# UnitPrice                      float64
# TotalPrice                     float64
# PaymentType                     object
# PromotionApplied                  bool
# DiscountAmount                 float64
# GiftWrap                          bool
# ShippingMethod                  object
# DeliveryTime                   float64
# Weather                         object
# Event                           object
# CustomerSatisfaction             int64
# ...

# %%
df['Gender'].dtypes
# Out:
# dtype('O')

# %%
ax = sns.countplot(x = 'Gender' , data= df)

for bars in ax.containers:
    ax.bar_label(bars, fmt="%.0f%%", label_type='center')

# %%
df.head()
# Out:
#    TransactionID       Date      Time  CustomerID  Age Gender Location  \
# 0              1 2020-12-24  07:27:59         441   27  Other  City_15
# 1              2 2022-11-18  14:36:39         340   43   Male  City_13
# 2              3 2019-12-26  20:23:50          31   25  Other   City_7
# 3              4 2018-11-13  23:08:08          39   64   Male  City_20
# 4              5 2020-12-13  04:38:08         344   26  Other  City_10
#
#    StoreID  OnlineOrderFlag  ProductID  ... PromotionApplied DiscountAmount  \
# 0      NaN             True        106  ...            False            0.0
# 1      NaN             True        816  ...             True            0.0
# 2     92.0            False        508  ...            False            0.0
# 3    100.0            False        710  ...            False            0.0
# 4     90.0            False        687  ...            False            0.0
#
#    GiftWrap  ShippingMethod  DeliveryTime Weather             Event  \
# ...

# %%
# compute percentage of each format
# percentage = []
# for i in range(df.shape[0]):
#     pct = (df.CustomerID[i].(Female).count() / df['CustomerID'].count()) * 100
#     percentage.append(round(pct,2))
#     df['Percentage'] = percentage

# percentage = []
# total_customers = df['CustomerID'].count()

# for i in range(df.shape[0]):
#     female_count = df.loc[i, 'CustomerID'].eq('Female').count()
#     pct = (female_count / total_customers) * 100
#     percentage.append(round(pct, 2))

# df['Percentage'] = percentage

# import numpy as np

percentage = []
total_customers = df.shape[0]

for i in range(total_customers):
    female_count = np.count_nonzero(df.loc[i, 'Gender'] == 'Female')
    pct = (female_count / total_customers) * 100
    percentage.append(round(pct, 2))

df['Percentage'] = percentage

# %%
df.head()
# Out:
#    TransactionID       Date      Time  CustomerID  Age Gender Location  \
# 0              1 2020-12-24  07:27:59         441   27  Other  City_15
# 1              2 2022-11-18  14:36:39         340   43   Male  City_13
# 2              3 2019-12-26  20:23:50          31   25  Other   City_7
# 3              4 2018-11-13  23:08:08          39   64   Male  City_20
# 4              5 2020-12-13  04:38:08         344   26  Other  City_10
#
#    StoreID  OnlineOrderFlag  ProductID  ... DiscountAmount GiftWrap  \
# 0      NaN             True        106  ...            0.0    False
# 1      NaN             True        816  ...            0.0     True
# 2     92.0            False        508  ...            0.0    False
# 3    100.0            False        710  ...            0.0     True
# 4     90.0            False        687  ...            0.0     True
#
#    ShippingMethod  DeliveryTime  Weather             Event  \
# 0        Standard           5.0    Snowy               NaN
# ...

# %%
Counts_female = df[df['Gender'] == 'Female']['CustomerID'].count()
Counts_female
# Out:
# 3298

# %%
counts_total = df['Gender'].value_counts()
counts_total
# Out:
# Gender
# Male      3385
# Other     3317
# Female    3298
# Name: count, dtype: int64

# %%
#Average Age
# female_perc = Counts_female/counts_total*100
# round_perc = round(female_perc,2)
# formatted_perc = f"{round_perc: .2%}"
# formatted_perc
df[df["Location"] == "City_1"][["Date","Location", "Age"]].groupby("Location").mean()
# Out:
#                                   Date        Age
# Location
# City_1   2021-07-08 21:15:20.930232576  44.416667

# %%
df.head()
# Out:
#    TransactionID       Date      Time  CustomerID  Age Gender Location  \
# 0              1 2020-12-24  07:27:59         441   27  Other  City_15
# 1              2 2022-11-18  14:36:39         340   43   Male  City_13
# 2              3 2019-12-26  20:23:50          31   25  Other   City_7
# 3              4 2018-11-13  23:08:08          39   64   Male  City_20
# 4              5 2020-12-13  04:38:08         344   26  Other  City_10
#
#    StoreID  OnlineOrderFlag  ProductID  ... PromotionApplied DiscountAmount  \
# 0      NaN             True        106  ...            False            0.0
# 1      NaN             True        816  ...             True            0.0
# 2     92.0            False        508  ...            False            0.0
# 3    100.0            False        710  ...            False            0.0
# 4     90.0            False        687  ...            False            0.0
#
#    GiftWrap  ShippingMethod  DeliveryTime Weather             Event  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   TransactionID         10000 non-null  int64
#  1   Date                  10000 non-null  datetime64[ns]
#  2   Time                  10000 non-null  object
#  3   CustomerID            10000 non-null  int64
#  4   Age                   10000 non-null  int64
#  5   Gender                10000 non-null  object
#  6   Location              10000 non-null  object
#  7   StoreID               4582 non-null   float64
#  8   OnlineOrderFlag       10000 non-null  bool
#  9   ProductID             10000 non-null  int64
#  10  ProductName           10000 non-null  object
#  11  Category              10000 non-null  object
#  12  Quantity              10000 non-null  int64
#  13  UnitPrice             10000 non-null  float64
#  14  TotalPrice            10000 non-null  float64
# ...

# %%
ax = sns.countplot(x = 'Age', data=df, hue= 'Gender') 
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_age = df.groupby(['Age'], as_index=False)['TotalPrice'].sum().sort_values(by = 'TotalPrice', ascending = False)
sales_age
sns.set(rc={'figure.figsize':(20,6)})
sns.barplot(x = 'Age', y= 'TotalPrice', data= sales_age)
# ax.bar_label(bars)
# Out:
# <Axes: xlabel='Age', ylabel='TotalPrice'>

# %% [markdown]
# age group 41-50 total price is got reduced

# %%
sales_Weather = df.groupby(['Month'], as_index= False)['TotalPrice'].sum()
sns.set(rc={'figure.figsize':(15,6)})
sns.barplot(x = 'Month', y= 'TotalPrice', data= sales_Weather)
# ax.bar_label(bars)
# Out:
# <Axes: xlabel='Month', ylabel='TotalPrice'>

# %%
df.head()
# Out:
#    TransactionID       Date      Time  CustomerID  Age Gender Location  \
# 0              1 2020-12-24  07:27:59         441   27  Other  City_15
# 1              2 2022-11-18  14:36:39         340   43   Male  City_13
# 2              3 2019-12-26  20:23:50          31   25  Other   City_7
# 3              4 2018-11-13  23:08:08          39   64   Male  City_20
# 4              5 2020-12-13  04:38:08         344   26  Other  City_10
#
#    StoreID  OnlineOrderFlag  ProductID  ... PromotionApplied DiscountAmount  \
# 0      NaN             True        106  ...            False            0.0
# 1      NaN             True        816  ...             True            0.0
# 2     92.0            False        508  ...            False            0.0
# 3    100.0            False        710  ...            False            0.0
# 4     90.0            False        687  ...            False            0.0
#
#    GiftWrap  ShippingMethod  DeliveryTime Weather             Event  \
# ...

# %%
df.groupby(['PaymentType'])['TotalPrice']

# %% [markdown]
# #TotalPrice based on payment type

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   TransactionID         10000 non-null  int64
#  1   Date                  10000 non-null  datetime64[ns]
#  2   Time                  10000 non-null  object
#  3   CustomerID            10000 non-null  int64
#  4   Age                   10000 non-null  int64
#  5   Gender                10000 non-null  object
#  6   Location              10000 non-null  object
#  7   StoreID               4582 non-null   float64
#  8   OnlineOrderFlag       10000 non-null  bool
#  9   ProductID             10000 non-null  int64
#  10  ProductName           10000 non-null  object
#  11  Category              10000 non-null  object
#  12  Quantity              10000 non-null  int64
#  13  UnitPrice             10000 non-null  float64
#  14  TotalPrice            10000 non-null  float64
# ...

# %%
sales_payment_type = df.groupby(['PaymentType'], as_index= False)['TotalPrice'].sum()
# df.groupby(['Month'], as_index= False)['TotalPrice'].sum()
sns.barplot(x = 'PaymentType', y = 'TotalPrice', data= sales_payment_type)
# Out:
# <Axes: xlabel='PaymentType', ylabel='TotalPrice'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   TransactionID         10000 non-null  int64
#  1   Date                  10000 non-null  datetime64[ns]
#  2   Time                  10000 non-null  object
#  3   CustomerID            10000 non-null  int64
#  4   Age                   10000 non-null  int64
#  5   Gender                10000 non-null  object
#  6   Location              10000 non-null  object
#  7   StoreID               4582 non-null   float64
#  8   OnlineOrderFlag       10000 non-null  bool
#  9   ProductID             10000 non-null  int64
#  10  ProductName           10000 non-null  object
#  11  Category              10000 non-null  object
#  12  Quantity              10000 non-null  int64
#  13  UnitPrice             10000 non-null  float64
#  14  TotalPrice            10000 non-null  float64
# ...

# %%
sales_category = df.groupby(['Category'], as_index= False)['TotalPrice'].sum().sort_values(by = 'TotalPrice', ascending=False)
sns.barplot(x= 'Category', y='TotalPrice', data = sales_category)
# Out:
# <Axes: xlabel='Category', ylabel='TotalPrice'>

# %%
df.head()
# Out:
#    TransactionID       Date      Time  CustomerID  Age Gender Location  \
# 0              1 2020-12-24  07:27:59         441   27  Other  City_15
# 1              2 2022-11-18  14:36:39         340   43   Male  City_13
# 2              3 2019-12-26  20:23:50          31   25  Other   City_7
# 3              4 2018-11-13  23:08:08          39   64   Male  City_20
# 4              5 2020-12-13  04:38:08         344   26  Other  City_10
#
#    StoreID  OnlineOrderFlag  ProductID  ... PromotionApplied DiscountAmount  \
# 0      NaN             True        106  ...            False            0.0
# 1      NaN             True        816  ...             True            0.0
# 2     92.0            False        508  ...            False            0.0
# 3    100.0            False        710  ...            False            0.0
# 4     90.0            False        687  ...            False            0.0
#
#    GiftWrap  ShippingMethod  DeliveryTime Weather             Event  \
# ...

# %% [markdown]
# Which Product ID had more Customer Satisfaction?

# %%
Selected_Columns = df[['TransactionID','Date','ProductID','Category','CustomerSatisfaction']]
Selected_Columns
condition = Selected_Columns['CustomerSatisfaction'] == 5
Result  = Selected_Columns[condition]
Result
# Out:
#       TransactionID       Date  ProductID     Category  CustomerSatisfaction
# 0                 1 2020-12-24        106         Toys                     5
# 7                 8 2020-12-03        829     Clothing                     5
# 11               12 2021-11-11        755  Decorations                     5
# 18               19 2018-12-13        332  Decorations                     5
# 30               31 2018-12-20        866  Decorations                     5
# ...             ...        ...        ...          ...                   ...
# 9986           9987 2023-11-22        532  Electronics                     5
# 9988           9989 2021-12-25         55  Decorations                     5
# 9989           9990 2021-12-14        850  Decorations                     5
# 9993           9994 2019-11-04         95  Electronics                     5
# 9994           9995 2019-12-12        345  Electronics                     5
#
# [1974 rows x 5 columns]

# %%
#Which Category has got more customer satisfaction

Selected_Columns = df[['TransactionID','Date','ProductID','Category','CustomerSatisfaction']]
Selected_Columns
Feedback_condition = Selected_Columns['CustomerSatisfaction'] == 5
Decorations_condition = Selected_Columns['Category'] == "Decorations"
Result  = Selected_Columns[Feedback_condition & Decorations_condition]
Result
# Out:
#       TransactionID       Date  ProductID     Category  CustomerSatisfaction
# 11               12 2021-11-11        755  Decorations                     5
# 18               19 2018-12-13        332  Decorations                     5
# 30               31 2018-12-20        866  Decorations                     5
# 61               62 2023-11-12        641  Decorations                     5
# 176             177 2019-11-10        847  Decorations                     5
# ...             ...        ...        ...          ...                   ...
# 9916           9917 2019-12-27        575  Decorations                     5
# 9966           9967 2022-12-05        664  Decorations                     5
# 9967           9968 2021-11-12        810  Decorations                     5
# 9988           9989 2021-12-25         55  Decorations                     5
# 9989           9990 2021-12-14        850  Decorations                     5
#
# [401 rows x 5 columns]

# %% [markdown]
# Decorations Category there are 401 transaction where customer Satisfaction is 5

# %%
Selected_Columns = df[['TransactionID','Date','ProductID','Category','CustomerSatisfaction']]
Selected_Columns
Feedback_condition = Selected_Columns['CustomerSatisfaction'] == 5
Electronics_condition = Selected_Columns['Category'] == "Electronics"
Result  = Selected_Columns[Feedback_condition & Electronics_condition]
Result
# Out:
#       TransactionID       Date  ProductID     Category  CustomerSatisfaction
# 37               38 2022-11-17        924  Electronics                     5
# 48               49 2019-11-30        525  Electronics                     5
# 58               59 2021-12-30        492  Electronics                     5
# 79               80 2021-11-17        704  Electronics                     5
# 89               90 2023-11-30        509  Electronics                     5
# ...             ...        ...        ...          ...                   ...
# 9902           9903 2023-12-23        216  Electronics                     5
# 9905           9906 2021-12-27        354  Electronics                     5
# 9986           9987 2023-11-22        532  Electronics                     5
# 9993           9994 2019-11-04         95  Electronics                     5
# 9994           9995 2019-12-12        345  Electronics                     5
#
# [405 rows x 5 columns]

# %% [markdown]
# Electronics Category there are 405 transaction where customer satisfaction is 5

# %%
df[(df['Category'] == 'Clothing') & (df['CustomerSatisfaction'] == 5)][['TransactionID', 'Date', 'ProductID', 'Category', 'CustomerSatisfaction']]
# Out:
#       TransactionID       Date  ProductID  Category  CustomerSatisfaction
# 7                 8 2020-12-03        829  Clothing                     5
# 34               35 2019-11-15        813  Clothing                     5
# 46               47 2020-11-03        348  Clothing                     5
# 67               68 2020-12-24        670  Clothing                     5
# 107             108 2020-12-25        485  Clothing                     5
# ...             ...        ...        ...       ...                   ...
# 9930           9931 2020-12-04        326  Clothing                     5
# 9936           9937 2020-12-18        417  Clothing                     5
# 9940           9941 2020-11-13        698  Clothing                     5
# 9974           9975 2021-12-18        966  Clothing                     5
# 9982           9983 2022-11-16        467  Clothing                     5
#
# [416 rows x 5 columns]

# %% [markdown]
# Customer Satisfaction for Clothing is ever higher than Electronics and Decorations

# %%
df[(df['Category'] == 'Toys') & (df['CustomerSatisfaction'] == 5)][['TransactionID', 'Date', 'ProductID', 'Category', 'CustomerSatisfaction']]['TransactionID'].count()
# Out:
# 367

# %% [markdown]
# The most least Customer satisfaction in terms of Category is Toys.

# %% [markdown]
# According to above four column the least and most customer satisfaction is in "Toys" and "Decorations" Category

# %%
df[(df['Category'] == 'Toys') & (df['CustomerSatisfaction'] == 5)][['ProductID', 'Category', 'CustomerSatisfaction']]['ProductID'].count()
df[(df['Category'] == 'Clothing') & (df['CustomerSatisfaction'] == 5)][['ProductID', 'Category', 'CustomerSatisfaction']]['ProductID'].count()
df[(df['Category'] == 'Electronics') & (df['CustomerSatisfaction'] == 5)][['ProductID', 'Category', 'CustomerSatisfaction']]['ProductID'].count()
df[(df['Category'] == 'Decorations') & (df['CustomerSatisfaction'] == 5)][['ProductID', 'Category', 'CustomerSatisfaction']]['ProductID'].count()
# Out:
# 401

# %% [markdown]
# SO the conclusion is ProductID and Transaction ID is primary key and Clothing is has got more Customer Satisfaction and Toys has got least Customer Satisfaction

# %% [markdown]
# Which Product ID had more Discount?

# %%
df[['ProductID','DiscountAmount']].groupby('ProductID')['DiscountAmount'].sum().sort_values(by = 'DiscountAmount', ascending = False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 df[['ProductID','DiscountAmount']].groupby('ProductID')['DiscountAmount'].sum().sort_values(by = 'DiscountAmount', ascending = False)
#
# TypeError: Series.sort_values() got an unexpected keyword argument 'by'

# %%
df[['ProductID', 'DiscountAmount']].groupby('ProductID')['DiscountAmount'].sum().sort_values(ascending=False)
# Out:
# ProductID
# 430    238.384212
# 245    215.082068
# 901    214.751981
# 851    210.381554
# 126    207.773836
#           ...
# 446      0.000000
# 983      0.000000
# 345      0.000000
# 471      0.000000
# 182      0.000000
# Name: DiscountAmount, Length: 1000, dtype: float64

# %% [markdown]
# It shows we have 1000 productID where Discount is given and 430 is the Product ID is the one which has got more Discount

# %% [markdown]
# df.info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   TransactionID         10000 non-null  int64
#  1   Date                  10000 non-null  datetime64[ns]
#  2   Time                  10000 non-null  object
#  3   CustomerID            10000 non-null  int64
#  4   Age                   10000 non-null  int64
#  5   Gender                10000 non-null  object
#  6   Location              10000 non-null  object
#  7   StoreID               4582 non-null   float64
#  8   OnlineOrderFlag       10000 non-null  bool
#  9   ProductID             10000 non-null  int64
#  10  ProductName           10000 non-null  object
#  11  Category              10000 non-null  object
#  12  Quantity              10000 non-null  int64
#  13  UnitPrice             10000 non-null  float64
#  14  TotalPrice            10000 non-null  float64
# ...

# %%
# df[df(['ProductID'] == 430)][['Date','Time','Age','Gender','ProductID','ProductName','TotalPrice','DiscountAmount','ShippingMethod']]
# df[(df['Category'] == 'Toys') & (df['CustomerSatisfaction'] == 5)][['ProductID', 'Category', 'CustomerSatisfaction']]['ProductID'].count()
df[df['ProductID'] == 430][['Date', 'Time', 'Age', 'Gender', 'ProductID', 'ProductName', 'TotalPrice', 'DiscountAmount', 'ShippingMethod']].sort_values(by = 'DiscountAmount', ascending=False)
# Out:
#            Date      Time  Age  Gender  ProductID          ProductName  \
# 7932 2018-12-05  05:53:16   43   Other        430  Decorations_Product
# 7617 2018-11-20  04:17:41   42  Female        430         Toys_Product
# 858  2020-11-16  19:19:20   64   Other        430     Clothing_Product
# 9727 2019-11-07  01:01:40   62  Female        430         Toys_Product
# 3207 2023-11-27  06:54:42   69  Female        430         Toys_Product
# 355  2019-11-24  00:04:56   69  Female        430  Electronics_Product
# 7680 2023-11-11  19:54:50   63    Male        430  Electronics_Product
# 5218 2019-11-17  19:57:57   66    Male        430     Clothing_Product
# 6635 2020-12-07  15:35:23   57   Other        430     Clothing_Product
# 7929 2019-11-13  16:15:28   30   Other        430         Food_Product
# 398  2023-11-04  12:43:04   70   Other        430     Clothing_Product
# 558  2023-12-28  10:37:49   59    Male        430         Toys_Product
# ...

# %% [markdown]
# Do Group by Gender and then Let's see what's the result you get

# %%
df[df['ProductID'] == 430][['Date', 'Time', 'Age', 'Gender', 'ProductID', 'ProductName', 'TotalPrice', 'DiscountAmount', 'ShippingMethod']].groupby('Gender')['DiscountAmount'].sum().sort_values( ascending=False)
# Out:
# Gender
# Female    116.570673
# Other      81.675996
# Male       40.137543
# Name: DiscountAmount, dtype: float64

# %% [markdown]
# Wow! Female has got more Discount

# %% [markdown]
# Why Female has got more Discount

# %%
df[['TransactionID','Gender','TotalPrice']].groupby('Gender')['TotalPrice'].sum().astype(int).apply('{:,}'.format).sort_values(ascending=False)
# Out:
# Gender
# Other     553,586
# Male      551,765
# Female    548,908
# Name: TotalPrice, dtype: object

# %% [markdown]
# In which city Females bought more and TotalPrice is higher comparatively

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   TransactionID         10000 non-null  int64
#  1   Date                  10000 non-null  datetime64[ns]
#  2   Time                  10000 non-null  object
#  3   CustomerID            10000 non-null  int64
#  4   Age                   10000 non-null  int64
#  5   Gender                10000 non-null  object
#  6   Location              10000 non-null  object
#  7   StoreID               4582 non-null   float64
#  8   OnlineOrderFlag       10000 non-null  bool
#  9   ProductID             10000 non-null  int64
#  10  ProductName           10000 non-null  object
#  11  Category              10000 non-null  object
#  12  Quantity              10000 non-null  int64
#  13  UnitPrice             10000 non-null  float64
#  14  TotalPrice            10000 non-null  float64
# ...

# %% [markdown]
# Major Part of sells coming from City_13

# %%
df[df['Gender'] == "Male"][['Gender','Location','TotalPrice']].groupby('Location')['TotalPrice'].sum().sort_values(ascending=False)
# Out:
# Location
# City_14    31294.478147
# City_12    30861.126510
# City_10    30094.906275
# City_2     29707.769560
# City_6     29637.951276
# City_19    28808.179687
# City_4     28512.640039
# City_18    28338.310200
# City_15    28069.880305
# City_17    27924.246470
# City_1     27120.932661
# City_7     26820.498721
# City_11    26558.861877
# City_20    26304.673645
# City_5     26106.719668
# City_8     25989.436849
# City_13    25900.020940
# City_16    25846.586455
# City_9     24925.657826
# City_3     22942.125768
# Name: TotalPrice, dtype: float64

# %% [markdown]
# What are those city in which Female has bought more compare to Male

# %% [markdown]
# female_sales = df[df['Gender'] == 'Female'][['Gender','Location','TotalPrice']].groupby('Location')['TotalPrice'].sum().sort_values(ascending = False)

# %%
F_Sal = df[df['Gender'] == 'Female'].groupby('Location')['TotalPrice'].sum()
M_Sal = df[df['Gender'] == 'Male'].groupby('Location')['TotalPrice'].sum()
T_Sal = F_Sal > M_Sal 
T_Sal
# Out:
# Location
# City_1      True
# City_10    False
# City_11     True
# City_12    False
# City_13     True
# City_14    False
# City_15     True
# City_16    False
# City_17    False
# City_18    False
# City_19    False
# City_2     False
# City_20     True
# City_3      True
# City_4     False
# City_5      True
# City_6     False
# City_7      True
# City_8     False
# City_9      True
# Name: TotalPrice, dtype: bool

# %% [markdown]
# There is males who is buying the most and the city which has more sales is City_13 but comparatively Females bought more than Males toys has less Customer Satisfaction and Clothing has got more customer Satisfaction Females has got more Discount then Males

# %%
df.head(6)
# Out:
#    TransactionID       Date      Time  CustomerID  Age Gender Location  \
# 0              1 2020-12-24  07:27:59         441   27  Other  City_15
# 1              2 2022-11-18  14:36:39         340   43   Male  City_13
# 2              3 2019-12-26  20:23:50          31   25  Other   City_7
# 3              4 2018-11-13  23:08:08          39   64   Male  City_20
# 4              5 2020-12-13  04:38:08         344   26  Other  City_10
# 5              6 2018-11-26  03:17:17         307   18   Male   City_4
#
#    StoreID  OnlineOrderFlag  ProductID  ... DiscountAmount GiftWrap  \
# 0      NaN             True        106  ...       0.000000    False
# 1      NaN             True        816  ...       0.000000     True
# 2     92.0            False        508  ...       0.000000    False
# 3    100.0            False        710  ...       0.000000     True
# 4     90.0            False        687  ...       0.000000     True
# ...

# %%
sns.histplot(df, x ='ShippingMethod' ,hue='Gender')
# Out:
# <Axes: xlabel='ShippingMethod', ylabel='Count'>

# %%
df.head(2)
# Out:
#    TransactionID       Date      Time  CustomerID  Age Gender Location  \
# 0              1 2020-12-24  07:27:59         441   27  Other  City_15
# 1              2 2022-11-18  14:36:39         340   43   Male  City_13
#
#    StoreID  OnlineOrderFlag  ProductID  ... DiscountAmount GiftWrap  \
# 0      NaN             True        106  ...            0.0    False
# 1      NaN             True        816  ...            0.0     True
#
#    ShippingMethod  DeliveryTime  Weather Event  CustomerSatisfaction  \
# 0        Standard           5.0        1   NaN                     5
# 1         Express           3.0        2   NaN                     2
#
#    ReturnFlag  Month       Sales
# 0       False  20-12  483.931273
# 1        True  22-11   95.279579
#
# [2 rows x 27 columns]

# %%
df.head(10)
# Out:
#    TransactionID       Date      Time  CustomerID  Age  Gender  Location  \
# 0              1 2020-12-24  07:27:59         441   27   Other       NaN
# 1              2 2022-11-18  14:36:39         441   43    Male       NaN
# 2              3 2019-12-26  20:23:50         441   25   Other       NaN
# 3              4 2018-11-13  23:08:08         441   64    Male       NaN
# 4              5 2020-12-13  04:38:08         441   26   Other       NaN
# 5              6 2018-11-26  03:17:17         441   18    Male       NaN
# 6              7 2020-12-08  08:26:56         441   63  Female       NaN
# 7              8 2020-12-03  16:02:24         441   48   Other       NaN
# 8              9 2020-11-10  14:41:38         441   58   Other       NaN
# 9             10 2019-11-16  00:08:13         441   41  Female       NaN
#
#    StoreID  OnlineOrderFlag  ProductID  ... DiscountAmount GiftWrap  \
# 0      NaN             True        106  ...       0.000000    False
# ...

# %%
df.head(2)
# Out:
#    TransactionID       Date      Time  CustomerID  Age Gender  Location  \
# 0              1 2020-12-24  07:27:59         441   27  Other       NaN
# 1              2 2022-11-18  14:36:39         340   43   Male       NaN
#
#    StoreID  OnlineOrderFlag  ProductID  ... DiscountAmount GiftWrap  \
# 0      NaN             True        106  ...            0.0    False
# 1      NaN             True        816  ...            0.0     True
#
#    ShippingMethod  DeliveryTime  Weather Event  CustomerSatisfaction  \
# 0        Standard           5.0        1   NaN                     5
# 1         Express           3.0        2   NaN                     2
#
#    ReturnFlag  Month       Sales
# 0       False  20-12  483.931273
# 1        True  22-11   95.279579
#
# [2 rows x 27 columns]

# %%
# sns.displot(df[df['CustomerID'] == 441]['Gender'])

# %%
sns.violinplot(data=df, x= 'CustomerID', y='TransactionID', hue='Gender')
# Out:
# <Axes: xlabel='CustomerID', ylabel='TransactionID'>
